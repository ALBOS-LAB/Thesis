# %%
import pandas as pd
import numpy as np
from numba import jit
import os

# Load your CSV file and parse the datetime index
ConsumptionPath = 'C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption'
df = pd.read_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/switched_data_columns.csv', index_col=0, parse_dates=True)

# Starting Tables for every optimization try
WorkingTables_Path = 'C:/Users/Nik/Documents/GitHub/Thesis/CSV/Working Tables'
DF_m2_Residential = pd.read_csv(os.path.join(WorkingTables_Path, 'DF_m2_Residential.csv'), sep=",", on_bad_lines='skip', header=0, index_col=0)
DF_m2_Industrial = pd.read_csv(os.path.join(WorkingTables_Path, 'DF_m2_Industrial.csv'), sep=",", on_bad_lines='skip', header=0, index_col=0)
DF_m2_Commercial = pd.read_csv(os.path.join(WorkingTables_Path, 'DF_m2_Commercial.csv'), sep=",", on_bad_lines='skip', header=0, index_col=0)

# Define Fourier Transform variation function without Numba due to unsupported FFT operations
def fourier_transform_variation(series, noise_level=0.1):
    fft_values = np.fft.fft(series)
    noise = np.random.normal(0, noise_level, size=len(fft_values))
    fft_values = fft_values * (1 + noise)
    return np.fft.ifft(fft_values).real

# Define function to add noise using Numba
@jit(nopython=True)
def add_noise_to_series(series, noise_level=0.05):
    noise = np.random.normal(0, noise_level, size=len(series))
    return series * (1 + noise)

# Define rolling perturbation function without Numba as it involves Pandas
def rolling_perturbation(series, window_size=24, perturbation_level=0.1):
    rolled = series.rolling(window=window_size, min_periods=1).mean()
    perturbation = np.random.normal(1, perturbation_level, size=len(series))
    return rolled * perturbation

# Helper function to apply all methods sequentially for each user
def apply_mixed_methods(df, base_column, users, prefix):
    # Assume df already has multiple curves; use a subset of them
    existing_columns = [col for col in df.columns if col.startswith(base_column)]
    
    # Generate a single mixed curve for each user
    transformed_df = pd.DataFrame(index=df.index)
    user_indices = list(users.index)
    
    for i, user in enumerate(user_indices):
        col = existing_columns[i % len(existing_columns)]  # Use available curves cyclically if fewer
        
        # Start with original curve
        mixed_curve = df[col].values
        
        # Apply Fourier Transform
        mixed_curve = fourier_transform_variation(mixed_curve, 0.1)
        
        # Apply Noise Addition
        mixed_curve = add_noise_to_series(mixed_curve, 0.05)
        
        # Apply Rolling Perturbation
        mixed_curve = rolling_perturbation(pd.Series(mixed_curve), 24, 0.1)
        
        # Add the resulting mixed curve to the DataFrame
        transformed_df[f'{prefix}_User_{user}_Mixed'] = mixed_curve
        
    return transformed_df

# Apply mixed methods to generate new consumption data based on existing curves
residential_consumption = apply_mixed_methods(df, 'Residential', DF_m2_Residential, 'Residential')
industrial_consumption = apply_mixed_methods(df, 'Industrial', DF_m2_Industrial, 'Industrial')
commercial_consumption = apply_mixed_methods(df, 'Commercial', DF_m2_Commercial, 'Commercial')

# Save the results to CSV files
residential_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Residential_Consumption_Optimized_From_Switched.csv')
industrial_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Industrial_Consumption_Optimized_From_Switched.csv')
commercial_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Commercial_Consumption_Optimized_From_Switched.csv')

print("Optimized consumption files created and saved using the new dataset.")

# %%
import pandas as pd
import numpy as np
from numba import jit
import os

# Load your CSV file and parse the datetime index
ConsumptionPath = 'C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption'
df = pd.read_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/switched_data_columns.csv', index_col=0, parse_dates=True)

# Starting Tables for every optimization try
WorkingTables_Path = 'C:/Users/Nik/Documents/GitHub/Thesis/CSV/Working Tables'
DF_m2_Residential = pd.read_csv(os.path.join(WorkingTables_Path, 'DF_m2_Residential.csv'), sep=",", on_bad_lines='skip', header=0, index_col=0)
DF_m2_Industrial = pd.read_csv(os.path.join(WorkingTables_Path, 'DF_m2_Industrial.csv'), sep=",", on_bad_lines='skip', header=0, index_col=0)
DF_m2_Commercial = pd.read_csv(os.path.join(WorkingTables_Path, 'DF_m2_Commercial.csv'), sep=",", on_bad_lines='skip', header=0, index_col=0)

# Define Fourier Transform variation function without Numba due to unsupported FFT operations
def fourier_transform_variation(series, noise_level=0.1):
    fft_values = np.fft.fft(series)
    noise = np.random.normal(0, noise_level, size=len(fft_values))
    fft_values = fft_values * (1 + noise)
    transformed_series = np.fft.ifft(fft_values).real
    return transformed_series

# Define function to add noise using Numba
@jit(nopython=True)
def add_noise_to_series(series, noise_level=0.05):
    noise = np.random.normal(0, noise_level, size=len(series))
    noisy_series = series * (1 + noise)
    return noisy_series

# Define rolling perturbation function without Numba as it involves Pandas
def rolling_perturbation(series, window_size=24, perturbation_level=0.1):
    rolled = series.rolling(window=window_size, min_periods=1).mean()
    perturbation = np.random.normal(1, perturbation_level, size=len(series))
    perturbed_series = rolled * perturbation
    return perturbed_series

# Helper function to apply all methods sequentially for each user
def apply_mixed_methods(df, base_column, users, prefix):
    # Assume df already has multiple curves; use a subset of them
    existing_columns = [col for col in df.columns if col.startswith(base_column)]
    
    # Generate a single mixed curve for each user
    curve_list = []
    user_indices = list(users.index)
    
    for i, user in enumerate(user_indices):
        col = existing_columns[i % len(existing_columns)]  # Use available curves cyclically if fewer
        
        # Start with original curve
        mixed_curve = df[col].values
        
        # Apply Fourier Transform
        mixed_curve = fourier_transform_variation(mixed_curve, 0.1)
        
        # Apply Noise Addition
        mixed_curve = add_noise_to_series(mixed_curve, 0.05)
        
        # Apply Rolling Perturbation
        mixed_curve = rolling_perturbation(pd.Series(mixed_curve, index=df.index), 24, 0.1)
        
        # Ensure that mixed_curve is converted to a numpy array after perturbation
        mixed_curve = mixed_curve.to_numpy()
        
        # Store the resulting mixed curve as a DataFrame column
        curve_list.append(pd.Series(mixed_curve, index=df.index, name=f'{prefix}_User_{user}_Mixed'))
        
        # Debugging: Print to verify the result at each step
        print(f'Processed curve for user {user}: mean={np.mean(mixed_curve):.2f}, std={np.std(mixed_curve):.2f}')
    
    # Combine all columns into a single DataFrame at once
    transformed_df = pd.concat(curve_list, axis=1)
    
    return transformed_df

# Apply mixed methods to generate new consumption data based on existing curves
residential_consumption = apply_mixed_methods(df, 'Residential', DF_m2_Residential, 'Residential')
industrial_consumption = apply_mixed_methods(df, 'Industrial', DF_m2_Industrial, 'Industrial')
commercial_consumption = apply_mixed_methods(df, 'Commercial', DF_m2_Commercial, 'Commercial')

# Save the results to CSV files
residential_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Residential_Consumption_Optimized_From_Switched_2.csv')
industrial_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Industrial_Consumption_Optimized_From_Switched_2.csv')
commercial_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Commercial_Consumption_Optimized_From_Switched_2.csv')

print("Optimized consumption files created and saved using the new dataset.")
# Out:
# Processed curve for user w158853557: mean=1.89, std=0.36
# Processed curve for user w158853558: mean=1.70, std=0.34
# Processed curve for user w158853559: mean=1.76, std=0.36
# Processed curve for user w211715359: mean=1.90, std=0.36
# Processed curve for user w246792829: mean=2.17, std=0.37
# Processed curve for user w276462198: mean=1.71, std=0.36
# Processed curve for user w276462425: mean=1.87, std=0.36
# Processed curve for user w276612247: mean=1.86, std=0.36
# Processed curve for user w276614920: mean=1.82, std=0.36
# Processed curve for user w276734031: mean=1.57, std=0.35
# Processed curve for user w298690124: mean=1.75, std=0.36
# Processed curve for user w298890320: mean=1.58, std=0.34
# Processed curve for user w298890321: mean=1.70, std=0.34
# Processed curve for user w298890322: mean=1.93, std=0.35
# Processed curve for user w298890323: mean=1.42, std=0.33
# Processed curve for user w298890324: mean=1.99, std=0.36
# Processed curve for user w298890325: mean=1.64, std=0.34
# Processed curve for user w298890326: mean=1.74, std=0.36
# Processed curve for user w298890327: mean=1.64, std=0.36
# Processed curve for user w298890328: mean=1.84, std=0.35
# Processed curve for user w298890329: mean=1.87, std=0.36
# Processed curve for user w298890330: mean=1.74, std=0.35
# Processed curve for user w298890331: mean=1.85, std=0.36
# Processed curve for user w298890332: mean=1.60, std=0.34
# Processed curve for user w298890333: mean=1.67, std=0.35
# Processed curve for user w306190105: mean=1.79, std=0.36
# Processed curve for user w306190106: mean=1.89, std=0.37
# Processed curve for user w310793316: mean=1.65, std=0.35
# Processed curve for user w312899217: mean=1.68, std=0.35
# Processed curve for user w332759543: mean=1.54, std=0.35
# Processed curve for user w332759544: mean=1.70, std=0.35
# Processed curve for user w332759545: mean=1.99, std=0.37
# Processed curve for user w332759546: mean=1.96, std=0.36
# Processed curve for user w332759547: mean=1.71, std=0.36
# Processed curve for user w332759548: mean=1.89, std=0.36
# Processed curve for user w332759549: mean=1.88, std=0.36
# Processed curve for user w332759550: mean=1.87, std=0.36
# Processed curve for user w332759551: mean=1.90, std=0.37
# Processed curve for user w332759552: mean=1.81, std=0.35
# Processed curve for user w332759553: mean=1.79, std=0.36
# Processed curve for user w332759555: mean=1.86, std=0.37
# Processed curve for user w332759556: mean=1.68, std=0.35
# Processed curve for user w332759557: mean=1.74, std=0.36
# Processed curve for user w332759558: mean=1.64, std=0.34
# Processed curve for user w332759559: mean=1.68, std=0.36
# Processed curve for user w370145123: mean=1.68, std=0.35
# Processed curve for user w404706714: mean=1.88, std=0.36
# Processed curve for user w404706716: mean=1.75, std=0.36
# Processed curve for user w404706718: mean=1.83, std=0.36
# Processed curve for user w404706719: mean=1.54, std=0.35
# Processed curve for user w451463764: mean=1.86, std=0.37
# Processed curve for user w451463765: mean=1.73, std=0.36
# Processed curve for user w451463766: mean=1.72, std=0.35
# Processed curve for user w451463767: mean=1.73, std=0.35
# Processed curve for user w451463768: mean=1.88, std=0.36
# Processed curve for user w451463769: mean=1.89, std=0.38
# Processed curve for user w457081001: mean=2.02, std=0.37
# Processed curve for user w457081002: mean=1.72, std=0.34
# Processed curve for user w457081003: mean=1.90, std=0.36
# Processed curve for user w457081004: mean=1.73, std=0.36
# Processed curve for user w457081005: mean=1.96, std=0.36
# Processed curve for user w457081006: mean=1.74, std=0.35
# Processed curve for user w469487122: mean=1.77, std=0.35
# Processed curve for user w469681591: mean=1.73, std=0.34
# Processed curve for user w470871310: mean=1.42, std=0.34
# Processed curve for user w470871311: mean=1.69, std=0.35
# Processed curve for user w470871312: mean=1.65, std=0.35
# Processed curve for user w470871313: mean=1.92, std=0.36
# Processed curve for user w470871806: mean=1.55, std=0.34
# Processed curve for user w470871807: mean=1.75, std=0.35
# Processed curve for user w470871808: mean=1.80, std=0.36
# Processed curve for user w470871809: mean=1.75, std=0.35
# Processed curve for user w470871810: mean=1.96, std=0.36
# Processed curve for user w470871811: mean=1.87, std=0.36
# Processed curve for user w470871812: mean=1.97, std=0.37
# Processed curve for user w470871813: mean=2.00, std=0.37
# Processed curve for user w470871814: mean=2.10, std=0.38
# Processed curve for user w470871815: mean=1.83, std=0.35
# Processed curve for user w470872321: mean=1.73, std=0.35
# Processed curve for user w470873221: mean=1.79, std=0.36
# Processed curve for user w470873223: mean=1.68, std=0.34
# Processed curve for user w470873225: mean=1.64, std=0.34
# Processed curve for user w470873227: mean=1.72, std=0.36
# Processed curve for user w470873229: mean=2.03, std=0.38
# Processed curve for user w470873231: mean=1.76, std=0.35
# Processed curve for user w470873233: mean=1.34, std=0.33
# Processed curve for user w470873235: mean=2.14, std=0.38
# Processed curve for user w470873237: mean=1.96, std=0.37
# Processed curve for user w470873239: mean=1.96, std=0.36
# Processed curve for user w470873241: mean=1.81, std=0.36
# Processed curve for user w470873244: mean=1.62, std=0.34
# Processed curve for user w470873246: mean=1.77, std=0.36
# Processed curve for user w470873248: mean=1.61, std=0.34
# Processed curve for user w470873250: mean=1.68, std=0.35
# Processed curve for user w470873253: mean=1.84, std=0.35
# Processed curve for user w470873255: mean=1.96, std=0.36
# Processed curve for user w470873257: mean=1.89, std=0.36
# Processed curve for user w470873259: mean=1.71, std=0.35
# Processed curve for user w470873379: mean=1.21, std=0.33
# Processed curve for user w470873566: mean=2.26, std=0.39
# Processed curve for user w470873567: mean=2.03, std=0.36
# Processed curve for user w470873568: mean=1.80, std=0.36
# Processed curve for user w470873569: mean=1.83, std=0.34
# Processed curve for user w470873570: mean=1.86, std=0.37
# Processed curve for user w470873571: mean=1.58, std=0.36
# Processed curve for user w470873572: mean=1.87, std=0.36
# Processed curve for user w470873573: mean=1.51, std=0.35
# Processed curve for user w470873574: mean=1.43, std=0.34
# Processed curve for user w471798098: mean=1.79, std=0.35
# Processed curve for user w471807964: mean=1.76, std=0.36
# Processed curve for user w471808314: mean=1.86, std=0.36
# Processed curve for user w471809767: mean=1.97, std=0.37
# Processed curve for user w471814282: mean=1.82, std=0.36
# Processed curve for user w471816936: mean=1.47, std=0.34
# Processed curve for user w471819853: mean=1.55, std=0.34
# Processed curve for user w471826095: mean=1.41, std=0.34
# Processed curve for user w471832770: mean=1.76, std=0.35
# Processed curve for user w471832841: mean=1.69, std=0.34
# Processed curve for user w471833372: mean=2.09, std=0.37
# Processed curve for user w471833472: mean=2.06, std=0.38
# Processed curve for user w471834403: mean=1.84, std=0.35
# Processed curve for user w471834445: mean=1.77, std=0.36
# Processed curve for user w471834676: mean=1.74, std=0.35
# Processed curve for user w471834801: mean=1.92, std=0.36
# Processed curve for user w471835958: mean=1.72, std=0.35
# Processed curve for user w471836858: mean=2.05, std=0.37
# Processed curve for user w471837297: mean=1.77, std=0.35
# Processed curve for user w471840202: mean=1.83, std=0.37
# Processed curve for user w471842406: mean=1.75, std=0.35
# Processed curve for user w471842407: mean=2.01, std=0.36
# Processed curve for user w471842409: mean=1.75, std=0.36
# Processed curve for user w471842881: mean=1.96, std=0.35
# Processed curve for user w471845254: mean=1.74, std=0.36
# Processed curve for user w471846970: mean=2.06, std=0.38
# Processed curve for user w471846971: mean=1.40, std=0.34
# Processed curve for user w471846972: mean=1.93, std=0.36
# Processed curve for user w471846973: mean=1.59, std=0.34
# Processed curve for user w471846974: mean=1.87, std=0.36
# Processed curve for user w471846975: mean=2.11, std=0.38
# Processed curve for user w471846976: mean=2.01, std=0.37
# Processed curve for user w471847150: mean=1.72, std=0.35
# Processed curve for user w471847152: mean=1.93, std=0.37
# Processed curve for user w471847153: mean=1.72, std=0.35
# Processed curve for user w471847569: mean=1.61, std=0.36
# Processed curve for user w471850275: mean=2.05, std=0.37
# Processed curve for user w471850276: mean=1.90, std=0.37
# Processed curve for user w471850277: mean=2.02, std=0.37
# Processed curve for user w471850313: mean=1.80, std=0.36
# Processed curve for user w471851495: mean=1.83, std=0.37
# Processed curve for user w471851496: mean=1.71, std=0.36
# Processed curve for user w471851497: mean=1.84, std=0.36
# Processed curve for user w471851499: mean=1.90, std=0.36
# Processed curve for user w471853909: mean=1.86, std=0.36
# Processed curve for user w471853912: mean=1.79, std=0.35
# Processed curve for user w471853914: mean=1.58, std=0.34
# Processed curve for user w471853916: mean=1.60, std=0.35
# Processed curve for user w471853918: mean=1.77, std=0.36
# Processed curve for user w471857523: mean=1.74, std=0.35
# Processed curve for user w471864947: mean=1.72, std=0.36
# Processed curve for user w471864948: mean=1.41, std=0.34
# Processed curve for user w471864949: mean=1.75, std=0.35
# Processed curve for user w471864950: mean=1.61, std=0.36
# Processed curve for user w471864951: mean=1.77, std=0.36
# Processed curve for user w471864952: mean=1.90, std=0.36
# Processed curve for user w471864953: mean=1.79, std=0.35
# Processed curve for user w471864954: mean=1.84, std=0.36
# Processed curve for user w471864955: mean=1.13, std=0.33
# Processed curve for user w471864956: mean=1.72, std=0.36
# Processed curve for user w471864957: mean=1.65, std=0.35
# Processed curve for user w471864958: mean=1.57, std=0.35
# Processed curve for user w471864959: mean=1.83, std=0.36
# Processed curve for user w471864960: mean=1.90, std=0.37
# Processed curve for user w471864961: mean=2.14, std=0.37
# Processed curve for user w471864962: mean=1.77, std=0.36
# Processed curve for user w471864963: mean=1.70, std=0.35
# Processed curve for user w471864964: mean=1.93, std=0.37
# Processed curve for user w471864965: mean=1.67, std=0.35
# Processed curve for user w471864966: mean=1.99, std=0.36
# Processed curve for user w471864967: mean=2.00, std=0.37
# Processed curve for user w471864968: mean=1.68, std=0.36
# Processed curve for user w471864969: mean=2.01, std=0.37
# Processed curve for user w471868674: mean=1.49, std=0.35
# Processed curve for user w471870777: mean=1.75, std=0.35
# Processed curve for user w471871956: mean=1.59, std=0.35
# Processed curve for user w471878469: mean=1.68, std=0.35
# Processed curve for user w471891097: mean=1.89, std=0.36
# Processed curve for user w471892177: mean=1.69, std=0.36
# Processed curve for user w471948183: mean=1.64, std=0.35
# Processed curve for user w471948184: mean=2.09, std=0.38
# Processed curve for user w471948185: mean=1.74, std=0.36
# Processed curve for user w471948186: mean=1.90, std=0.36
# Processed curve for user w471948569: mean=1.78, std=0.35
# Processed curve for user w471952171: mean=1.64, std=0.35
# Processed curve for user w471955677: mean=1.61, std=0.35
# Processed curve for user w471955678: mean=1.61, std=0.35
# Processed curve for user w471955679: mean=1.91, std=0.36
# Processed curve for user w471955680: mean=1.73, std=0.35
# Processed curve for user w471955681: mean=1.56, std=0.34
# Processed curve for user w471955682: mean=1.88, std=0.35
# Processed curve for user w471955683: mean=1.80, std=0.36
# Processed curve for user w471972076: mean=1.85, std=0.37
# Processed curve for user w471973969: mean=1.67, std=0.34
# Processed curve for user w471973970: mean=1.73, std=0.35
# Processed curve for user w471973971: mean=1.77, std=0.35
# Processed curve for user w471973972: mean=1.76, std=0.37
# Processed curve for user w471973973: mean=1.82, std=0.35
# Processed curve for user w471973974: mean=1.72, std=0.35
# Processed curve for user w471973975: mean=1.76, std=0.34
# Processed curve for user w471973976: mean=1.93, std=0.36
# Processed curve for user w471974874: mean=1.92, std=0.37
# Processed curve for user w471974875: mean=1.67, std=0.35
# Processed curve for user w471974877: mean=1.75, std=0.36
# Processed curve for user w471974878: mean=1.74, std=0.36
# Processed curve for user w471974879: mean=1.95, std=0.37
# Processed curve for user w471974880: mean=1.66, std=0.36
# Processed curve for user w471974882: mean=1.86, std=0.36
# Processed curve for user w471974884: mean=1.74, std=0.36
# Processed curve for user w471974886: mean=1.64, std=0.35
# Processed curve for user w471974887: mean=2.01, std=0.37
# Processed curve for user w471978552: mean=1.48, std=0.35
# Processed curve for user w471978553: mean=1.48, std=0.35
# Processed curve for user w471978554: mean=1.70, std=0.35
# Processed curve for user w471978555: mean=1.67, std=0.35
# Processed curve for user w471978556: mean=1.78, std=0.36
# Processed curve for user w471978558: mean=1.38, std=0.34
# Processed curve for user w471978559: mean=1.40, std=0.35
# Processed curve for user w471978560: mean=1.77, std=0.36
# Processed curve for user w471979883: mean=1.87, std=0.36
# Processed curve for user w471979884: mean=1.69, std=0.35
# Processed curve for user w471979886: mean=1.99, std=0.37
# Processed curve for user w471979887: mean=2.12, std=0.38
# Processed curve for user w472275200: mean=2.15, std=0.37
# Processed curve for user w472275205: mean=2.11, std=0.38
# Processed curve for user w472276948: mean=1.90, std=0.35
# Processed curve for user w472276949: mean=1.91, std=0.36
# Processed curve for user w472394912: mean=1.69, std=0.36
# Processed curve for user w472398031: mean=1.72, std=0.36
# Processed curve for user w472398032: mean=1.65, std=0.35
# Processed curve for user w472398033: mean=1.77, std=0.35
# Processed curve for user w472398034: mean=1.76, std=0.36
# Processed curve for user w472398035: mean=2.02, std=0.36
# Processed curve for user w472398036: mean=1.73, std=0.36
# Processed curve for user w472398037: mean=1.50, std=0.34
# Processed curve for user w472398038: mean=2.11, std=0.37
# Processed curve for user w472398039: mean=1.54, std=0.34
# Processed curve for user w472398040: mean=1.59, std=0.34
# Processed curve for user w472398041: mean=1.87, std=0.36
# Processed curve for user w472398042: mean=1.70, std=0.35
# Processed curve for user w472398043: mean=1.58, std=0.34
# Processed curve for user w472398044: mean=1.98, std=0.36
# Processed curve for user w472398045: mean=1.80, std=0.36
# Processed curve for user w472398046: mean=1.93, std=0.37
# Processed curve for user w472398047: mean=1.98, std=0.36
# Processed curve for user w472398048: mean=1.76, std=0.35
# Processed curve for user w472398049: mean=1.81, std=0.36
# Processed curve for user w472398050: mean=1.78, std=0.36
# Processed curve for user w472398320: mean=1.74, std=0.35
# Processed curve for user w472398321: mean=1.81, std=0.34
# Processed curve for user w472398322: mean=1.73, std=0.35
# Processed curve for user w472398323: mean=1.95, std=0.36
# Processed curve for user w472398325: mean=1.53, std=0.34
# Processed curve for user w472398326: mean=1.60, std=0.34
# Processed curve for user w472398327: mean=1.72, std=0.35
# Processed curve for user w472398328: mean=1.86, std=0.36
# Processed curve for user w472398329: mean=1.71, std=0.35
# Processed curve for user w472410490: mean=1.40, std=0.34
# Processed curve for user w472410803: mean=1.65, std=0.35
# Processed curve for user w472411270: mean=1.65, std=0.34
# Processed curve for user w472420795: mean=1.86, std=0.35
# Processed curve for user w472420796: mean=1.66, std=0.34
# Processed curve for user w472420798: mean=1.71, std=0.35
# Processed curve for user w472420799: mean=1.60, std=0.36
# Processed curve for user w472420800: mean=2.07, std=0.38
# Processed curve for user w472420802: mean=1.90, std=0.36
# Processed curve for user w472420803: mean=1.72, std=0.35
# Processed curve for user w472420804: mean=1.99, std=0.36
# Processed curve for user w472420805: mean=1.54, std=0.35
# Processed curve for user w472421176: mean=1.83, std=0.35
# Processed curve for user w472421177: mean=1.83, std=0.36
# Processed curve for user w472421178: mean=1.55, std=0.33
# Processed curve for user w472421179: mean=1.68, std=0.36
# Processed curve for user w472425844: mean=1.71, std=0.37
# Processed curve for user w472425845: mean=1.92, std=0.36
# Processed curve for user w472425846: mean=1.70, std=0.35
# Processed curve for user w472427812: mean=2.09, std=0.37
# Processed curve for user w472599969: mean=1.72, std=0.35
# Processed curve for user w473438841: mean=1.77, std=0.37
# Processed curve for user w473438842: mean=1.91, std=0.37
# Processed curve for user w473446197: mean=1.55, std=0.34
# Processed curve for user w473446199: mean=1.61, std=0.34
# Processed curve for user w473446201: mean=1.89, std=0.38
# Processed curve for user w473446203: mean=1.78, std=0.35
# Processed curve for user w473446205: mean=1.53, std=0.35
# Processed curve for user w473446208: mean=1.79, std=0.36
# Processed curve for user w473446210: mean=1.61, std=0.35
# Processed curve for user w473446212: mean=1.74, std=0.35
# Processed curve for user w473446214: mean=1.59, std=0.34
# Processed curve for user w473446967: mean=1.80, std=0.36
# Processed curve for user w473446968: mean=1.79, std=0.36
# Processed curve for user w473446969: mean=1.77, std=0.35
# Processed curve for user w473446970: mean=1.93, std=0.36
# Processed curve for user w473446971: mean=1.70, std=0.35
# Processed curve for user w473446972: mean=1.96, std=0.36
# Processed curve for user w473446973: mean=1.96, std=0.37
# Processed curve for user w473446974: mean=2.00, std=0.38
# Processed curve for user w473446975: mean=1.26, std=0.34
# Processed curve for user w473446976: mean=1.78, std=0.35
# Processed curve for user w473446977: mean=2.00, std=0.38
# Processed curve for user w473446978: mean=1.70, std=0.35
# Processed curve for user w473446979: mean=1.89, std=0.35
# Processed curve for user w473446980: mean=1.72, std=0.34
# Processed curve for user w473446981: mean=1.67, std=0.35
# Processed curve for user w473446982: mean=1.93, std=0.36
# Processed curve for user w473450643: mean=1.99, std=0.37
# Processed curve for user w473450644: mean=1.60, std=0.35
# Processed curve for user w473450645: mean=1.84, std=0.36
# Processed curve for user w473450646: mean=1.93, std=0.36
# Processed curve for user w473450647: mean=1.39, std=0.33
# Processed curve for user w473450648: mean=1.83, std=0.35
# Processed curve for user w473450649: mean=1.59, std=0.35
# Processed curve for user w473450652: mean=1.60, std=0.35
# Processed curve for user w473450653: mean=1.59, std=0.35
# Processed curve for user w473452470: mean=1.48, std=0.34
# Processed curve for user w473452471: mean=1.70, std=0.35
# Processed curve for user w473452472: mean=2.06, std=0.37
# Processed curve for user w473452473: mean=1.48, std=0.34
# Processed curve for user w473452474: mean=1.83, std=0.37
# Processed curve for user w473452475: mean=1.72, std=0.36
# Processed curve for user w473452476: mean=1.94, std=0.36
# Processed curve for user w473452477: mean=1.64, std=0.35
# Processed curve for user w473452478: mean=2.09, std=0.36
# Processed curve for user w473452479: mean=1.54, std=0.35
# Processed curve for user w473452481: mean=1.79, std=0.35
# Processed curve for user w473452482: mean=2.18, std=0.38
# Processed curve for user w473452484: mean=1.76, std=0.36
# Processed curve for user w473452485: mean=1.80, std=0.36
# Processed curve for user w473452486: mean=1.63, std=0.35
# Processed curve for user w473452487: mean=1.60, std=0.34
# Processed curve for user w473452490: mean=2.11, std=0.38
# Processed curve for user w473453431: mean=1.71, std=0.36
# Processed curve for user w473454168: mean=1.88, std=0.35
# Processed curve for user w473454169: mean=1.67, std=0.35
# Processed curve for user w473454170: mean=1.87, std=0.36
# Processed curve for user w473457215: mean=1.96, std=0.36
# Processed curve for user w474613056: mean=1.74, std=0.35
# Processed curve for user w474613057: mean=1.49, std=0.34
# Processed curve for user w474613993: mean=1.84, std=0.35
# Processed curve for user w474613994: mean=1.81, std=0.35
# Processed curve for user w474904367: mean=1.88, std=0.35
# Processed curve for user w475448882: mean=1.72, std=0.35
# Processed curve for user w475616869: mean=1.89, std=0.36
# Processed curve for user w475952844: mean=1.86, std=0.36
# Processed curve for user w475952845: mean=1.71, std=0.33
# Processed curve for user w475952847: mean=2.06, std=0.37
# Processed curve for user w475952848: mean=1.54, std=0.34
# Processed curve for user w475952849: mean=1.92, std=0.36
# Processed curve for user w475952850: mean=1.74, std=0.35
# Processed curve for user w475952851: mean=1.81, std=0.36
# Processed curve for user w475952853: mean=1.82, std=0.36
# Processed curve for user w475952854: mean=1.77, std=0.36
# Processed curve for user w475954104: mean=1.58, std=0.34
# Processed curve for user w475954106: mean=2.11, std=0.37
# Processed curve for user w475954107: mean=1.75, std=0.36
# Processed curve for user w475954109: mean=1.52, std=0.34
# Processed curve for user w475954110: mean=1.60, std=0.35
# Processed curve for user w475954111: mean=1.73, std=0.35
# Processed curve for user w475954112: mean=1.69, std=0.34
# Processed curve for user w475954113: mean=1.88, std=0.35
# Processed curve for user w475955277: mean=1.86, std=0.36
# Processed curve for user w475955278: mean=1.84, std=0.35
# Processed curve for user w475955279: mean=1.54, std=0.35
# Processed curve for user w475955280: mean=1.92, std=0.36
# Processed curve for user w475955281: mean=1.70, std=0.36
# Processed curve for user w475955282: mean=1.62, std=0.35
# Processed curve for user w475955283: mean=1.83, std=0.35
# Processed curve for user w475956672: mean=2.02, std=0.36
# Processed curve for user w475956674: mean=1.86, std=0.37
# Processed curve for user w475956675: mean=1.44, std=0.35
# Processed curve for user w475956676: mean=1.95, std=0.36
# Processed curve for user w475956677: mean=1.95, std=0.36
# Processed curve for user w475956916: mean=1.69, std=0.35
# Processed curve for user w475956917: mean=2.06, std=0.37
# Processed curve for user w475956918: mean=1.68, std=0.35
# Processed curve for user w475957211: mean=1.75, std=0.36
# Processed curve for user w475957245: mean=1.66, std=0.36
# Processed curve for user w475958563: mean=1.37, std=0.34
# Processed curve for user w475958564: mean=1.98, std=0.37
# Processed curve for user w475958566: mean=1.92, std=0.37
# Processed curve for user w475958567: mean=1.69, std=0.34
# Processed curve for user w475958568: mean=1.65, std=0.36
# Processed curve for user w475958784: mean=1.95, std=0.36
# Processed curve for user w475958785: mean=1.87, std=0.36
# Processed curve for user w475958786: mean=1.62, std=0.35
# Processed curve for user w475958787: mean=1.69, std=0.35
# Processed curve for user w475959192: mean=1.93, std=0.36
# Processed curve for user w475959194: mean=1.71, std=0.35
# Processed curve for user w475959196: mean=1.99, std=0.36
# Processed curve for user w475959199: mean=1.80, std=0.36
# Processed curve for user w475959201: mean=1.75, std=0.36
# Processed curve for user w475959203: mean=2.14, std=0.37
# Processed curve for user w475959205: mean=1.88, std=0.36
# Processed curve for user w475959207: mean=1.86, std=0.36
# Processed curve for user w475959784: mean=1.94, std=0.37
# Processed curve for user w475959786: mean=1.72, std=0.35
# Processed curve for user w475959788: mean=1.51, std=0.34
# Processed curve for user w475959790: mean=2.01, std=0.37
# Processed curve for user w475959791: mean=1.66, std=0.34
# Processed curve for user w475959793: mean=1.69, std=0.36
# Processed curve for user w475959795: mean=1.91, std=0.36
# Processed curve for user w475959796: mean=1.79, std=0.36
# Processed curve for user w475960225: mean=1.41, std=0.33
# Processed curve for user w475960226: mean=1.49, std=0.35
# Processed curve for user w475960227: mean=1.64, std=0.35
# Processed curve for user w475960228: mean=2.23, std=0.38
# Processed curve for user w475960229: mean=1.69, std=0.35
# Processed curve for user w475960230: mean=1.35, std=0.34
# Processed curve for user w475960231: mean=1.99, std=0.36
# Processed curve for user w475961441: mean=1.45, std=0.35
# Processed curve for user w475962567: mean=1.71, std=0.34
# Processed curve for user w475962568: mean=1.72, std=0.34
# Processed curve for user w475962569: mean=1.75, std=0.36
# Processed curve for user w475962570: mean=1.51, std=0.34
# Processed curve for user w475962571: mean=1.86, std=0.36
# Processed curve for user w475962572: mean=2.18, std=0.37
# Processed curve for user w476739538: mean=1.59, std=0.35
# Processed curve for user w476740810: mean=1.79, std=0.36
# Processed curve for user w476740811: mean=1.88, std=0.37
# Processed curve for user w476740812: mean=1.30, std=0.33
# Processed curve for user w476740813: mean=1.85, std=0.36
# Processed curve for user w476740814: mean=1.65, std=0.35
# Processed curve for user w476740815: mean=1.62, std=0.36
# Processed curve for user w476740816: mean=1.70, std=0.35
# Processed curve for user w476740817: mean=1.86, std=0.36
# Processed curve for user w476740818: mean=1.77, std=0.36
# Processed curve for user w476740819: mean=1.81, std=0.37
# Processed curve for user w476740820: mean=1.81, std=0.36
# Processed curve for user w476741257: mean=1.55, std=0.34
# Processed curve for user w476741258: mean=1.64, std=0.35
# Processed curve for user w476741259: mean=1.83, std=0.36
# Processed curve for user w476741260: mean=1.67, std=0.34
# Processed curve for user w476741261: mean=1.68, std=0.36
# Processed curve for user w476741263: mean=1.97, std=0.36
# Processed curve for user w476744087: mean=1.55, std=0.33
# Processed curve for user w476744088: mean=1.75, std=0.36
# Processed curve for user w476744090: mean=1.95, std=0.37
# Processed curve for user w476744091: mean=1.90, std=0.37
# Processed curve for user w476744093: mean=1.81, std=0.36
# Processed curve for user w476744095: mean=1.94, std=0.36
# Processed curve for user w476744096: mean=1.99, std=0.37
# Processed curve for user w476744098: mean=1.43, std=0.35
# Processed curve for user w476746953: mean=1.80, std=0.36
# Processed curve for user w476746954: mean=1.70, std=0.35
# Processed curve for user w476746955: mean=1.53, std=0.35
# Processed curve for user w476746956: mean=2.10, std=0.36
# Processed curve for user w476746957: mean=1.95, std=0.36
# Processed curve for user w476746958: mean=1.37, std=0.34
# Processed curve for user w476746959: mean=1.73, std=0.35
# Processed curve for user w476746960: mean=1.52, std=0.34
# Processed curve for user w476746961: mean=1.31, std=0.34
# Processed curve for user w476746963: mean=1.58, std=0.34
# Processed curve for user w476748190: mean=1.83, std=0.36
# Processed curve for user w476748191: mean=1.74, std=0.35
# Processed curve for user w476748192: mean=1.95, std=0.38
# Processed curve for user w476748193: mean=1.97, std=0.36
# Processed curve for user w476748194: mean=1.89, std=0.37
# Processed curve for user w476748195: mean=1.61, std=0.33
# Processed curve for user w476748196: mean=1.97, std=0.37
# Processed curve for user w476748198: mean=1.81, std=0.36
# Processed curve for user w476748200: mean=1.84, std=0.36
# Processed curve for user w476748201: mean=1.88, std=0.35
# Processed curve for user w476748202: mean=1.71, std=0.36
# Processed curve for user w476748203: mean=1.74, std=0.35
# Processed curve for user w476748298: mean=2.15, std=0.38
# Processed curve for user w476753359: mean=1.47, std=0.34
# Processed curve for user w476753361: mean=2.08, std=0.37
# Processed curve for user w476753362: mean=1.75, std=0.36
# Processed curve for user w476754010: mean=1.36, std=0.33
# Processed curve for user w476754011: mean=1.99, std=0.37
# Processed curve for user w476754097: mean=1.98, std=0.37
# Processed curve for user w477680539: mean=1.63, std=0.35
# Processed curve for user w477681559: mean=1.62, std=0.35
# Processed curve for user w477683533: mean=1.96, std=0.37
# Processed curve for user w477683534: mean=1.45, std=0.34
# Processed curve for user w477683535: mean=1.60, std=0.34
# Processed curve for user w477683536: mean=1.64, std=0.36
# Processed curve for user w477683537: mean=1.65, std=0.35
# Processed curve for user w477683538: mean=1.98, std=0.36
# Processed curve for user w477683539: mean=1.79, std=0.35
# Processed curve for user w477683540: mean=1.86, std=0.35
# Processed curve for user w477683541: mean=1.81, std=0.35
# Processed curve for user w477683542: mean=1.75, std=0.36
# Processed curve for user w477683543: mean=1.79, std=0.35
# Processed curve for user w477683544: mean=1.51, std=0.34
# Processed curve for user w477683545: mean=2.02, std=0.36
# Processed curve for user w477684041: mean=1.77, std=0.35
# Processed curve for user w477684042: mean=1.47, std=0.34
# Processed curve for user w477684043: mean=1.61, std=0.35
# Processed curve for user w477684044: mean=1.63, std=0.35
# Processed curve for user w477684045: mean=1.71, std=0.35
# Processed curve for user w477684046: mean=1.67, std=0.35
# Processed curve for user w477684047: mean=1.75, std=0.36
# Processed curve for user w477684575: mean=1.71, std=0.36
# Processed curve for user w477684576: mean=1.68, std=0.36
# Processed curve for user w477684577: mean=1.50, std=0.34
# Processed curve for user w477684578: mean=1.97, std=0.36
# Processed curve for user w477684579: mean=1.76, std=0.36
# Processed curve for user w477684580: mean=1.94, std=0.37
# Processed curve for user w477684581: mean=1.98, std=0.36
# Processed curve for user w477684582: mean=1.67, std=0.36
# Processed curve for user w477684583: mean=1.44, std=0.34
# Processed curve for user w477684584: mean=1.99, std=0.36
# Processed curve for user w478152793: mean=1.73, std=0.36
# Processed curve for user w478152794: mean=1.12, std=0.32
# Processed curve for user w478152795: mean=1.82, std=0.37
# Processed curve for user w478152796: mean=2.03, std=0.38
# Processed curve for user w478152797: mean=1.80, std=0.36
# Processed curve for user w478152798: mean=1.77, std=0.36
# Processed curve for user w478152799: mean=2.05, std=0.37
# Processed curve for user w478152800: mean=1.71, std=0.36
# Processed curve for user w478152801: mean=2.04, std=0.38
# Processed curve for user w478152802: mean=1.86, std=0.35
# Processed curve for user w478152803: mean=1.76, std=0.35
# Processed curve for user w478152804: mean=1.95, std=0.35
# Processed curve for user w478152805: mean=1.98, std=0.37
# Processed curve for user w478153501: mean=2.12, std=0.37
# Processed curve for user w478153502: mean=1.74, std=0.35
# Processed curve for user w478153503: mean=1.71, std=0.35
# Processed curve for user w478153506: mean=1.68, std=0.36
# Processed curve for user w478153507: mean=1.48, std=0.33
# Processed curve for user w478154189: mean=1.59, std=0.34
# Processed curve for user w478154190: mean=1.89, std=0.37
# Processed curve for user w478154191: mean=1.46, std=0.34
# Processed curve for user w478154192: mean=1.92, std=0.36
# Processed curve for user w478154193: mean=1.74, std=0.34
# Processed curve for user w478154194: mean=1.90, std=0.36
# Processed curve for user w478154602: mean=1.56, std=0.36
# Processed curve for user w478154604: mean=1.66, std=0.35
# Processed curve for user w478154606: mean=1.67, std=0.36
# Processed curve for user w478155442: mean=1.68, std=0.35
# Processed curve for user w478155444: mean=2.02, std=0.37
# Processed curve for user w478155445: mean=1.69, std=0.35
# Processed curve for user w478155447: mean=1.28, std=0.32
# Processed curve for user w478155448: mean=1.96, std=0.38
# Processed curve for user w478155449: mean=1.77, std=0.35
# Processed curve for user w478155450: mean=1.58, std=0.35
# Processed curve for user w478155452: mean=1.55, std=0.33
# Processed curve for user w478155736: mean=1.99, std=0.37
# Processed curve for user w478155737: mean=2.00, std=0.37
# Processed curve for user w478155738: mean=1.50, std=0.35
# Processed curve for user w478155739: mean=1.64, std=0.36
# Processed curve for user w478155740: mean=1.81, std=0.35
# Processed curve for user w478155741: mean=1.74, std=0.36
# Processed curve for user w478156799: mean=1.66, std=0.35
# Processed curve for user w478156800: mean=1.68, std=0.36
# Processed curve for user w478156801: mean=1.57, std=0.34
# Processed curve for user w478156802: mean=1.62, std=0.35
# Processed curve for user w478156803: mean=1.72, std=0.34
# Processed curve for user w478156804: mean=1.55, std=0.34
# Processed curve for user w478156806: mean=1.68, std=0.35
# Processed curve for user w478156808: mean=1.56, std=0.34
# Processed curve for user w478156809: mean=1.56, std=0.36
# Processed curve for user w478156810: mean=1.76, std=0.36
# Processed curve for user w478156811: mean=1.78, std=0.36
# Processed curve for user w478156812: mean=1.48, std=0.34
# Processed curve for user w478157346: mean=1.92, std=0.37
# Processed curve for user w478157349: mean=1.87, std=0.36
# Processed curve for user w478157351: mean=1.68, std=0.35
# Processed curve for user w478157353: mean=2.04, std=0.37
# Processed curve for user w478157355: mean=1.57, std=0.34
# Processed curve for user w478157357: mean=1.75, std=0.36
# Processed curve for user w478158102: mean=1.85, std=0.36
# Processed curve for user w478158103: mean=1.73, std=0.34
# Processed curve for user w478158104: mean=1.44, std=0.34
# Processed curve for user w478158105: mean=1.66, std=0.36
# Processed curve for user w478158108: mean=1.77, std=0.35
# Processed curve for user w478158109: mean=1.61, std=0.34
# Processed curve for user w478158110: mean=1.91, std=0.36
# Processed curve for user w478158894: mean=1.71, std=0.36
# Processed curve for user w478158895: mean=1.91, std=0.37
# Processed curve for user w478158896: mean=1.63, std=0.36
# Processed curve for user w478158898: mean=1.71, std=0.36
# Processed curve for user w478158899: mean=1.84, std=0.36
# Processed curve for user w478158900: mean=1.84, std=0.37
# Processed curve for user w478158901: mean=2.00, std=0.37
# Processed curve for user w478158902: mean=1.84, std=0.37
# Processed curve for user w478158903: mean=1.68, std=0.36
# Processed curve for user w478160679: mean=1.40, std=0.34
# Processed curve for user w478160680: mean=1.77, std=0.35
# Processed curve for user w478160681: mean=1.86, std=0.35
# Processed curve for user w478160682: mean=2.03, std=0.37
# Processed curve for user w478160847: mean=1.94, std=0.36
# Processed curve for user w478160849: mean=1.86, std=0.36
# Processed curve for user w478160850: mean=1.70, std=0.37
# Processed curve for user w478160851: mean=1.89, std=0.36
# Processed curve for user w478160852: mean=1.78, std=0.36
# Processed curve for user w478161213: mean=1.82, std=0.37
# Processed curve for user w478161214: mean=1.87, std=0.36
# Processed curve for user w478161215: mean=1.42, std=0.35
# Processed curve for user w478161216: mean=1.81, std=0.37
# Processed curve for user w478161217: mean=1.97, std=0.37
# Processed curve for user w478161218: mean=1.71, std=0.36
# Processed curve for user w478161219: mean=2.15, std=0.38
# Processed curve for user w478161220: mean=1.81, std=0.36
# Processed curve for user w478161221: mean=1.67, std=0.36
# Processed curve for user w478161705: mean=1.72, std=0.35
# Processed curve for user w478161706: mean=1.98, std=0.36
# Processed curve for user w478161707: mean=1.90, std=0.36
# Processed curve for user w478161708: mean=1.74, std=0.36
# Processed curve for user w478161709: mean=2.11, std=0.38
# Processed curve for user w478161710: mean=1.72, std=0.34
# Processed curve for user w478161711: mean=1.80, std=0.35
# Processed curve for user w478162375: mean=1.76, std=0.35
# Processed curve for user w478822307: mean=1.66, std=0.35
# Processed curve for user w478824512: mean=2.09, std=0.38
# Processed curve for user w482560351: mean=1.69, std=0.36
# Processed curve for user w482560352: mean=1.99, std=0.37
# Processed curve for user w482663195: mean=1.95, std=0.37
# Processed curve for user w482663198: mean=1.76, std=0.37
# Processed curve for user w482663200: mean=1.57, std=0.34
# Processed curve for user w482663203: mean=1.84, std=0.36
# Processed curve for user w482663205: mean=1.70, std=0.35
# Processed curve for user w482663208: mean=1.65, std=0.35
# Processed curve for user w482663209: mean=1.89, std=0.37
# Processed curve for user w482663211: mean=1.79, std=0.35
# Processed curve for user w482663212: mean=1.51, std=0.36
# Processed curve for user w482663220: mean=1.78, std=0.35
# Processed curve for user w482663222: mean=1.72, std=0.36
# Processed curve for user w482663224: mean=1.49, std=0.33
# Processed curve for user w482663226: mean=1.81, std=0.36
# Processed curve for user w482663228: mean=1.78, std=0.37
# Processed curve for user w482663231: mean=1.43, std=0.35
# Processed curve for user w482663236: mean=1.78, std=0.35
# Processed curve for user w482663239: mean=1.71, std=0.35
# Processed curve for user w482663242: mean=1.53, std=0.33
# Processed curve for user w482663245: mean=1.27, std=0.34
# Processed curve for user w482663246: mean=1.74, std=0.36
# Processed curve for user w482663249: mean=1.72, std=0.37
# Processed curve for user w482663286: mean=2.03, std=0.38
# Processed curve for user w482822607: mean=1.80, std=0.35
# Processed curve for user w482822608: mean=1.67, std=0.36
# Processed curve for user w482822609: mean=2.01, std=0.38
# Processed curve for user w482822610: mean=1.85, std=0.36
# Processed curve for user w482822611: mean=1.43, std=0.35
# Processed curve for user w482823212: mean=1.72, std=0.35
# Processed curve for user w482823382: mean=1.83, std=0.36
# Processed curve for user w482823383: mean=1.53, std=0.34
# Processed curve for user w482823384: mean=1.91, std=0.35
# Processed curve for user w482824925: mean=2.01, std=0.37
# Processed curve for user w482824926: mean=1.67, std=0.35
# Processed curve for user w482824929: mean=1.84, std=0.37
# Processed curve for user w482824938: mean=1.61, std=0.34
# Processed curve for user w482824939: mean=2.00, std=0.38
# Processed curve for user w482824941: mean=1.84, std=0.36
# Processed curve for user w482824942: mean=1.56, std=0.36
# Processed curve for user w482825477: mean=2.02, std=0.36
# Processed curve for user w482847061: mean=1.85, std=0.36
# Processed curve for user w482847062: mean=1.50, std=0.34
# Processed curve for user w482847063: mean=1.64, std=0.34
# Processed curve for user w484126501: mean=1.91, std=0.37
# Processed curve for user w484126502: mean=1.71, std=0.35
# Processed curve for user w484126503: mean=1.51, std=0.35
# Processed curve for user w484126505: mean=1.86, std=0.36
# Processed curve for user w484126507: mean=1.59, std=0.34
# Processed curve for user w484126508: mean=1.68, std=0.34
# Processed curve for user w484126509: mean=1.82, std=0.37
# Processed curve for user w484126510: mean=1.79, std=0.36
# Processed curve for user w484126511: mean=1.56, std=0.35
# Processed curve for user w484126782: mean=1.62, std=0.35
# Processed curve for user w484126783: mean=1.82, std=0.37
# Processed curve for user w484127281: mean=1.58, std=0.35
# Processed curve for user w484127282: mean=1.71, std=0.35
# Processed curve for user w484127283: mean=1.38, std=0.34
# Processed curve for user w484128205: mean=1.38, std=0.33
# Processed curve for user w484128207: mean=1.79, std=0.36
# Processed curve for user w484128208: mean=1.77, std=0.35
# Processed curve for user w484128210: mean=1.77, std=0.37
# Processed curve for user w484129380: mean=1.80, std=0.36
# Processed curve for user w484129381: mean=2.00, std=0.37
# Processed curve for user w484129383: mean=1.73, std=0.36
# Processed curve for user w484130354: mean=1.82, std=0.35
# Processed curve for user w484130355: mean=1.88, std=0.37
# Processed curve for user w484130356: mean=1.70, std=0.35
# Processed curve for user w484130357: mean=2.08, std=0.36
# Processed curve for user w484132540: mean=1.82, std=0.35
# Processed curve for user w484132541: mean=1.71, std=0.36
# Processed curve for user w484132542: mean=1.53, std=0.35
# Processed curve for user w484132543: mean=1.60, std=0.35
# Processed curve for user w484132544: mean=1.86, std=0.35
# Processed curve for user w484132545: mean=1.61, std=0.34
# Processed curve for user w484132912: mean=1.49, std=0.35
# Processed curve for user w484132914: mean=1.79, std=0.35
# Processed curve for user w484132917: mean=1.92, std=0.37
# Processed curve for user w484132919: mean=1.70, std=0.36
# Processed curve for user w484133405: mean=1.54, std=0.34
# Processed curve for user w484133407: mean=1.67, std=0.34
# Processed curve for user w484133991: mean=2.12, std=0.37
# Processed curve for user w484133992: mean=1.77, std=0.36
# Processed curve for user w484133993: mean=1.96, std=0.37
# Processed curve for user w484133994: mean=1.99, std=0.38
# Processed curve for user w484133995: mean=1.92, std=0.35
# Processed curve for user w484133996: mean=1.65, std=0.34
# Processed curve for user w484133997: mean=1.86, std=0.35
# Processed curve for user w484133998: mean=1.59, std=0.36
# Processed curve for user w484139827: mean=1.74, std=0.36
# Processed curve for user w484149718: mean=1.84, std=0.36
# Processed curve for user w484149830: mean=1.59, std=0.34
# Processed curve for user w486177189: mean=1.58, std=0.36
# Processed curve for user w486177190: mean=1.68, std=0.35
# Processed curve for user w486177191: mean=1.93, std=0.37
# Processed curve for user w486177192: mean=1.96, std=0.36
# Processed curve for user w486177193: mean=1.65, std=0.35
# Processed curve for user w486177194: mean=1.87, std=0.36
# Processed curve for user w486177195: mean=2.00, std=0.36
# Processed curve for user w486177196: mean=1.96, std=0.37
# Processed curve for user w486177197: mean=1.58, std=0.34
# Processed curve for user w486177198: mean=1.78, std=0.36
# Processed curve for user w486177199: mean=1.64, std=0.35
# Processed curve for user w486177200: mean=1.90, std=0.36
# Processed curve for user w486177201: mean=1.79, std=0.36
# Processed curve for user w486177202: mean=1.49, std=0.35
# Processed curve for user w486177203: mean=1.93, std=0.36
# Processed curve for user w486177204: mean=1.89, std=0.36
# Processed curve for user w486177205: mean=1.82, std=0.35
# Processed curve for user w486177608: mean=1.16, std=0.33
# Processed curve for user w486177609: mean=1.84, std=0.35
# Processed curve for user w486177610: mean=1.91, std=0.38
# Processed curve for user w486177611: mean=1.81, std=0.35
# Processed curve for user w486178083: mean=1.90, std=0.36
# Processed curve for user w486178084: mean=1.72, std=0.35
# Processed curve for user w486178085: mean=1.89, std=0.36
# Processed curve for user w486178086: mean=1.59, std=0.35
# Processed curve for user w486178087: mean=1.64, std=0.35
# Processed curve for user w486178088: mean=1.55, std=0.35
# Processed curve for user w486178089: mean=1.65, std=0.35
# Processed curve for user w486178090: mean=1.60, std=0.35
# Processed curve for user w486178091: mean=1.81, std=0.36
# Processed curve for user w486178092: mean=1.46, std=0.34
# Processed curve for user w486178093: mean=1.87, std=0.37
# Processed curve for user w486178094: mean=1.87, std=0.35
# Processed curve for user w486178203: mean=1.89, std=0.36
# Processed curve for user w486180355: mean=1.46, std=0.34
# Processed curve for user w486180357: mean=1.75, std=0.35
# Processed curve for user w486180358: mean=1.62, std=0.34
# Processed curve for user w486184336: mean=1.55, std=0.35
# Processed curve for user w486184338: mean=1.66, std=0.35
# Processed curve for user w486184340: mean=1.77, std=0.35
# Processed curve for user w486184343: mean=1.75, std=0.35
# Processed curve for user w486184347: mean=1.64, std=0.34
# Processed curve for user w486184349: mean=1.69, std=0.35
# Processed curve for user w486185613: mean=1.97, std=0.36
# Processed curve for user w486185614: mean=1.81, std=0.36
# Processed curve for user w486185615: mean=1.74, std=0.36
# Processed curve for user w486185616: mean=1.87, std=0.37
# Processed curve for user w486185617: mean=1.92, std=0.36
# Processed curve for user w486185618: mean=1.79, std=0.36
# Processed curve for user w486185619: mean=1.46, std=0.34
# Processed curve for user w486185620: mean=2.04, std=0.37
# Processed curve for user w486186226: mean=1.86, std=0.37
# Processed curve for user w486186227: mean=1.75, std=0.36
# Processed curve for user w486186228: mean=1.81, std=0.36
# Processed curve for user w486186229: mean=1.70, std=0.34
# Processed curve for user w486186231: mean=1.75, std=0.35
# Processed curve for user w486186232: mean=1.63, std=0.34
# Processed curve for user w486186233: mean=1.99, std=0.35
# Processed curve for user w486186234: mean=1.88, std=0.36
# Processed curve for user w486186494: mean=1.81, std=0.35
# Processed curve for user w486186495: mean=1.73, std=0.36
# Processed curve for user w486186496: mean=1.34, std=0.34
# Processed curve for user w486186498: mean=1.54, std=0.35
# Processed curve for user w486187263: mean=1.98, std=0.37
# Processed curve for user w486187264: mean=1.53, std=0.35
# Processed curve for user w486187265: mean=1.91, std=0.36
# Processed curve for user w486187266: mean=2.09, std=0.37
# Processed curve for user w486187267: mean=1.40, std=0.34
# Processed curve for user w486187268: mean=1.83, std=0.35
# Processed curve for user w486187270: mean=1.92, std=0.37
# Processed curve for user w486187271: mean=1.87, std=0.35
# Processed curve for user w486187272: mean=1.72, std=0.35
# Processed curve for user w486187274: mean=1.62, std=0.36
# Processed curve for user w486187275: mean=1.98, std=0.37
# Processed curve for user w486187276: mean=1.86, std=0.35
# Processed curve for user w486244621: mean=1.64, std=0.34
# Processed curve for user w486244622: mean=1.56, std=0.35
# Processed curve for user w486244623: mean=1.80, std=0.37
# Processed curve for user w486244624: mean=1.67, std=0.34
# Processed curve for user w486244625: mean=1.82, std=0.36
# Processed curve for user w486244626: mean=1.68, std=0.35
# Processed curve for user w486244627: mean=1.73, std=0.35
# Processed curve for user w486244628: mean=1.70, std=0.35
# Processed curve for user w486244629: mean=1.55, std=0.34
# Processed curve for user w486244630: mean=1.82, std=0.36
# Processed curve for user w486244631: mean=1.62, std=0.34
# Processed curve for user w486244632: mean=1.68, std=0.35
# Processed curve for user w486244633: mean=1.85, std=0.36
# Processed curve for user w486244634: mean=1.76, std=0.35
# Processed curve for user w486244786: mean=1.81, std=0.35
# Processed curve for user w486244787: mean=1.28, std=0.34
# Processed curve for user w486244788: mean=1.70, std=0.34
# Processed curve for user w487707869: mean=1.55, std=0.34
# Processed curve for user w487707870: mean=1.72, std=0.36
# Processed curve for user w487707871: mean=1.87, std=0.36
# Processed curve for user w487707872: mean=1.58, std=0.35
# Processed curve for user w487707873: mean=1.71, std=0.35
# Processed curve for user w487707875: mean=1.69, std=0.35
# Processed curve for user w487707879: mean=1.90, std=0.36
# Processed curve for user w487707881: mean=1.87, std=0.36
# Processed curve for user w487707882: mean=1.68, std=0.34
# Processed curve for user w487707883: mean=1.73, std=0.37
# Processed curve for user w487707884: mean=1.87, std=0.35
# Processed curve for user w487708422: mean=1.62, std=0.35
# Processed curve for user w487708424: mean=1.69, std=0.34
# Processed curve for user w487708426: mean=1.55, std=0.34
# Processed curve for user w487708427: mean=1.84, std=0.34
# Processed curve for user w487708428: mean=1.47, std=0.34
# Processed curve for user w487708429: mean=1.67, std=0.37
# Processed curve for user w487708430: mean=1.49, std=0.34
# Processed curve for user w487710245: mean=1.83, std=0.37
# Processed curve for user w487710246: mean=1.83, std=0.36
# Processed curve for user w487710247: mean=1.75, std=0.35
# Processed curve for user w487710248: mean=1.49, std=0.34
# Processed curve for user w487710249: mean=1.93, std=0.35
# Processed curve for user w487710251: mean=1.96, std=0.37
# Processed curve for user w487713342: mean=1.84, std=0.36
# Processed curve for user w487713344: mean=1.95, std=0.36
# Processed curve for user w487713345: mean=1.68, std=0.35
# Processed curve for user w487713347: mean=1.57, std=0.35
# Processed curve for user w487713349: mean=1.55, std=0.34
# Processed curve for user w487713351: mean=1.41, std=0.34
# Processed curve for user w487713353: mean=1.83, std=0.36
# Processed curve for user w487713355: mean=1.63, std=0.34
# Processed curve for user w487713357: mean=1.97, std=0.36
# Processed curve for user w487713358: mean=1.69, std=0.36
# Processed curve for user w487713360: mean=1.71, std=0.35
# Processed curve for user w487713362: mean=1.60, std=0.35
# Processed curve for user w487713364: mean=1.38, std=0.35
# Processed curve for user w487713366: mean=1.59, std=0.35
# Processed curve for user w487713368: mean=1.98, std=0.37
# Processed curve for user w487713371: mean=1.86, std=0.35
# Processed curve for user w487713373: mean=1.63, std=0.34
# Processed curve for user w487713375: mean=1.66, std=0.35
# Processed curve for user w487713377: mean=2.00, std=0.37
# Processed curve for user w487714405: mean=1.38, std=0.35
# ...
# Processed curve for user w471960417: mean=13.02, std=2.46
# Processed curve for user w471961055: mean=13.26, std=2.46
# Processed curve for user w471961056: mean=12.03, std=2.37
# Processed curve for user w471963602: mean=9.72, std=2.30
# Processed curve for user w471964854: mean=11.50, std=2.32
# Processed curve for user w471966641: mean=12.33, std=2.36
# Processed curve for user w471968311: mean=11.84, std=2.39
# Processed curve for user w472275200: mean=11.46, std=2.41
# Processed curve for user w472275205: mean=11.62, std=2.39
# Processed curve for user w472275544: mean=8.20, std=2.20
# Processed curve for user w472369085: mean=11.35, std=2.28
# Processed curve for user w472392544: mean=14.03, std=2.47
# Processed curve for user w472398031: mean=10.22, std=2.29
# Processed curve for user w472411995: mean=12.27, std=2.38
# Processed curve for user w472418907: mean=12.79, std=2.45
# Processed curve for user w472420794: mean=13.07, std=2.46
# Processed curve for user w472423762: mean=11.46, std=2.38
# Processed curve for user w472427810: mean=11.15, std=2.37
# Processed curve for user w472427813: mean=11.27, std=2.36
# Processed curve for user w473444135: mean=12.37, std=2.37
# Processed curve for user w473453431: mean=11.32, std=2.30
# Processed curve for user w475448882: mean=14.37, std=2.48
# Processed curve for user w475449239: mean=11.85, std=2.47
# Processed curve for user w475616869: mean=11.01, std=2.25
# Processed curve for user w475691042: mean=9.97, std=2.30
# Processed curve for user w475720681: mean=12.54, std=2.37
# Processed curve for user w475726035: mean=10.00, std=2.28
# Processed curve for user w475743546: mean=11.74, std=2.32
# Processed curve for user w475955282: mean=13.95, std=2.46
# Processed curve for user w476744098: mean=9.38, std=2.22
# Processed curve for user w476748298: mean=11.64, std=2.34
# Processed curve for user w476751523: mean=12.22, std=2.37
# Processed curve for user w476752904: mean=11.63, std=2.27
# Processed curve for user w476754097: mean=13.11, std=2.35
# Processed curve for user w476767732: mean=11.15, std=2.26
# Processed curve for user w477680540: mean=11.87, std=2.38
# Processed curve for user w477681559: mean=12.43, std=2.43
# Processed curve for user w477683531: mean=10.52, std=2.27
# Processed curve for user w478154604: mean=10.48, std=2.32
# Processed curve for user w478824512: mean=11.79, std=2.43
# Processed curve for user w482560351: mean=8.97, std=2.27
# Processed curve for user w482663286: mean=11.42, std=2.39
# Processed curve for user w482663294: mean=9.58, std=2.26
# Processed curve for user w482692533: mean=10.83, std=2.31
# Processed curve for user w482693532: mean=11.98, std=2.37
# Processed curve for user w482824932: mean=11.41, std=2.32
# Processed curve for user w482824933: mean=12.15, std=2.41
# Processed curve for user w482824940: mean=9.72, std=2.22
# Processed curve for user w482824945: mean=12.16, std=2.32
# Processed curve for user w482847065: mean=9.30, std=2.26
# Processed curve for user w484142317: mean=10.98, std=2.34
# Processed curve for user w484149718: mean=13.60, std=2.48
# Processed curve for user w486178725: mean=11.70, std=2.36
# Processed curve for user w486180357: mean=11.08, std=2.34
# Processed curve for user w488116637: mean=11.40, std=2.31
# Processed curve for user w494844375: mean=12.59, std=2.40
# Processed curve for user w495288557: mean=12.35, std=2.39
# Processed curve for user w495289198: mean=10.75, std=2.24
# Processed curve for user w495289201: mean=11.51, std=2.33
# Processed curve for user w504624472: mean=10.45, std=2.23
# Processed curve for user w504625974: mean=10.90, std=2.35
# Processed curve for user w504627428: mean=11.83, std=2.39
# Processed curve for user w506258669: mean=12.54, std=2.37
# Processed curve for user w506258673: mean=11.72, std=2.40
# Processed curve for user w506258680: mean=13.54, std=2.44
# Processed curve for user w506274183: mean=11.13, std=2.28
# Processed curve for user w506294760: mean=12.01, std=2.40
# Processed curve for user w506297655: mean=12.25, std=2.40
# Processed curve for user w506297776: mean=8.74, std=2.19
# Processed curve for user w510573954: mean=13.27, std=2.41
# Processed curve for user w516262156: mean=10.89, std=2.38
# Processed curve for user w520426091: mean=12.75, std=2.41
# Processed curve for user w520426092: mean=13.14, std=2.46
# Processed curve for user w528153537: mean=11.89, std=2.31
# Processed curve for user w533817233: mean=13.41, std=2.44
# Processed curve for user w533817237: mean=11.21, std=2.35
# Processed curve for user w533818162: mean=12.11, std=2.42
# Processed curve for user w533818170: mean=11.64, std=2.30
# Processed curve for user w533818171: mean=11.58, std=2.28
# Processed curve for user w533818175: mean=12.74, std=2.50
# Processed curve for user w533818266: mean=9.16, std=2.21
# Processed curve for user w533819771: mean=11.98, std=2.39
# Processed curve for user w533819772: mean=11.06, std=2.29
# Processed curve for user w533819775: mean=11.95, std=2.33
# Processed curve for user w533819776: mean=11.27, std=2.35
# Processed curve for user w533821089: mean=13.05, std=2.47
# Processed curve for user w533821090: mean=11.30, std=2.36
# Processed curve for user w533822055: mean=11.03, std=2.31
# Processed curve for user w534569497: mean=10.90, std=2.29
# Processed curve for user w534569501: mean=12.13, std=2.38
# Processed curve for user w534573301: mean=10.02, std=2.31
# Processed curve for user w535343094: mean=10.45, std=2.28
# Processed curve for user w535346947: mean=12.20, std=2.40
# Processed curve for user w535359998: mean=11.38, std=2.28
# Processed curve for user w535368180: mean=13.36, std=2.40
# Processed curve for user w541775517: mean=14.63, std=2.51
# Processed curve for user w541779229: mean=11.91, std=2.37
# Processed curve for user w541914145: mean=11.92, std=2.33
# Processed curve for user w541923135: mean=10.47, std=2.32
# Processed curve for user w541965092: mean=12.37, std=2.32
# Processed curve for user w541965101: mean=11.44, std=2.39
# Processed curve for user w541969488: mean=11.01, std=2.36
# Processed curve for user w543183748: mean=14.51, std=2.52
# Processed curve for user w543183749: mean=11.57, std=2.36
# Processed curve for user w543189524: mean=9.56, std=2.22
# Processed curve for user w554132282: mean=12.60, std=2.36
# Processed curve for user w574606560: mean=10.53, std=2.25
# Processed curve for user w574606573: mean=11.72, std=2.36
# Processed curve for user w574612623: mean=12.59, std=2.44
# Processed curve for user w574617561: mean=12.83, std=2.47
# Processed curve for user w574617568: mean=9.85, std=2.27
# Processed curve for user w574617569: mean=12.43, std=2.33
# Processed curve for user w579393918: mean=10.66, std=2.25
# Processed curve for user w579405944: mean=10.05, std=2.24
# Processed curve for user w579411994: mean=11.70, std=2.36
# Processed curve for user w579411999: mean=10.91, std=2.33
# Processed curve for user w579412003: mean=11.91, std=2.36
# Processed curve for user w586115796: mean=11.83, std=2.30
# Processed curve for user w586115799: mean=10.56, std=2.35
# Processed curve for user w588230674: mean=10.80, std=2.36
# Processed curve for user w588230676: mean=10.80, std=2.30
# Processed curve for user w588230681: mean=10.56, std=2.34
# Processed curve for user w588230696: mean=10.77, std=2.29
# Processed curve for user w588232920: mean=13.17, std=2.45
# Processed curve for user w588237662: mean=12.72, std=2.39
# Processed curve for user w588237665: mean=14.74, std=2.53
# Processed curve for user w588237910: mean=11.15, std=2.35
# Processed curve for user w588238459: mean=13.45, std=2.48
# Processed curve for user w588814368: mean=12.17, std=2.36
# Processed curve for user w592485510: mean=12.27, std=2.49
# Processed curve for user w592487869: mean=11.13, std=2.30
# Processed curve for user w592487872: mean=12.40, std=2.37
# Processed curve for user w592487873: mean=11.54, std=2.36
# Processed curve for user w592487874: mean=9.61, std=2.21
# Processed curve for user w592488496: mean=9.00, std=2.21
# Processed curve for user w592488500: mean=11.41, std=2.40
# Processed curve for user w592781545: mean=12.69, std=2.35
# Processed curve for user w592868589: mean=10.58, std=2.31
# Processed curve for user w592868597: mean=10.26, std=2.31
# Processed curve for user w592868598: mean=11.68, std=2.38
# Processed curve for user w592874727: mean=11.81, std=2.45
# Processed curve for user w601833450: mean=12.51, std=2.42
# Processed curve for user w601844646: mean=14.17, std=2.49
# Processed curve for user w603537107: mean=10.07, std=2.23
# Processed curve for user w603537108: mean=10.50, std=2.36
# Processed curve for user w605088179: mean=12.36, std=2.50
# Processed curve for user w620980889: mean=11.86, std=2.30
# Processed curve for user w620984134: mean=11.94, std=2.34
# Processed curve for user w620985278: mean=12.40, std=2.46
# Processed curve for user w621838492: mean=10.32, std=2.30
# Processed curve for user w622149918: mean=12.39, std=2.39
# Processed curve for user w625669094: mean=12.63, std=2.35
# Processed curve for user w625671304: mean=10.45, std=2.29
# Processed curve for user w625671306: mean=13.83, std=2.44
# Processed curve for user w629297578: mean=13.09, std=2.47
# Processed curve for user w629297579: mean=11.77, std=2.41
# Processed curve for user w630331862: mean=11.80, std=2.35
# Processed curve for user w631683572: mean=11.69, std=2.33
# Processed curve for user w631683573: mean=10.50, std=2.26
# Processed curve for user w631683975: mean=10.18, std=2.30
# Processed curve for user w631819075: mean=11.52, std=2.38
# Processed curve for user w631819126: mean=10.87, std=2.39
# Processed curve for user w631821517: mean=10.27, std=2.30
# Processed curve for user w632582578: mean=9.97, std=2.23
# Processed curve for user w633731452: mean=12.25, std=2.36
# Processed curve for user w640498558: mean=9.49, std=2.28
# Processed curve for user w642007899: mean=12.31, std=2.42
# Processed curve for user w642007939: mean=13.60, std=2.46
# Processed curve for user w643528419: mean=10.65, std=2.25
# Processed curve for user w643944386: mean=10.76, std=2.37
# Processed curve for user w645087064: mean=10.99, std=2.39
# Processed curve for user w657651680: mean=12.36, std=2.40
# Processed curve for user w662743557: mean=12.73, std=2.34
# Processed curve for user w662743558: mean=12.52, std=2.34
# Processed curve for user w781512958: mean=13.05, std=2.43
# Processed curve for user w784598628: mean=11.48, std=2.37
# Processed curve for user w881761417: mean=11.33, std=2.38
# Processed curve for user w881761418: mean=11.16, std=2.31
# Processed curve for user w881761419: mean=11.46, std=2.31
# Processed curve for user w881761420: mean=11.61, std=2.31
# Processed curve for user w881761421: mean=12.46, std=2.41
# Processed curve for user w881761422: mean=11.82, std=2.41
# Processed curve for user w881761423: mean=13.53, std=2.49
# Processed curve for user w881761424: mean=12.73, std=2.35
# Processed curve for user w881761425: mean=12.25, std=2.38
# Processed curve for user w881761426: mean=12.28, std=2.32
# Processed curve for user w881761430: mean=11.60, std=2.40
# Processed curve for user w881941841: mean=12.24, std=2.35
# Processed curve for user w979842352: mean=12.19, std=2.38
# Processed curve for user w979842353: mean=11.91, std=2.38
# Processed curve for user w979844292: mean=10.23, std=2.28
# Processed curve for user w980611822: mean=11.89, std=2.35
# Processed curve for user w980611823: mean=10.99, std=2.31
# Processed curve for user w980611824: mean=12.50, std=2.32
# Processed curve for user w1083205991: mean=11.42, std=2.34
# Processed curve for user w1083279085: mean=12.48, std=2.34
# Processed curve for user w1083279086: mean=9.95, std=2.27
# Processed curve for user w1083279087: mean=14.56, std=2.50
# Processed curve for user w1083279088: mean=11.78, std=2.24
# Processed curve for user w1083279089: mean=12.22, std=2.43
# Processed curve for user w1083279095: mean=11.46, std=2.34
# Processed curve for user w1083279096: mean=11.42, std=2.25
# Processed curve for user w1083279097: mean=8.88, std=2.30
# Processed curve for user w1083279098: mean=13.07, std=2.49
# Processed curve for user w1083279099: mean=11.30, std=2.28
# Processed curve for user w1083279100: mean=8.62, std=2.20
# Processed curve for user w1083279101: mean=12.90, std=2.43
# Processed curve for user w1083279102: mean=10.62, std=2.32
# Processed curve for user w1190124851: mean=12.78, std=2.39
# Processed curve for user w1190124852: mean=12.68, std=2.33
# Processed curve for user w1207656377: mean=12.33, std=2.36
# Processed curve for user w469491620: mean=12.38, std=2.45
# Processed curve for user w476753360: mean=11.35, std=2.32
# Processed curve for user w535351168: mean=14.81, std=2.51
# Processed curve for user w543183760: mean=9.95, std=2.26
# Processed curve for user w543184811: mean=8.96, std=2.23
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15896/4152769749.py in <module>
#      80
#      81 # Save the results to CSV files
# ---> 82 residential_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Residential_Consumption_Optimized_From_Switched_2.csv')
#      83 industrial_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Industrial_Consumption_Optimized_From_Switched_2.csv')
#      84 commercial_consumption.to_csv('C:/Users/Nik/Documents/GitHub/Thesis/CSV/Consumption/Commercial_Consumption_Optimized_From_Switched_2.csv')
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3718         )
#    3719
# -> 3720         return DataFrameRenderer(formatter).to_csv(
#    3721             path_or_buf,
#    3722             lineterminator=lineterminator,
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1187             formatter=self.fmt,
#    1188         )
# -> 1189         csv_formatter.save()
#    1190
#    1191         if created_buffer:
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     259             )
#     260
# --> 261             self._save()
#     262
#     263     def _save(self) -> None:
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\io\formats\csvs.py in _save(self)
#     264         if self._need_to_save_header:
#     265             self._save_header()
# --> 266         self._save_body()
#     267
#     268     def _save_header(self) -> None:
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\io\formats\csvs.py in _save_body(self)
#     302             if start_i >= end_i:
#     303                 break
# --> 304             self._save_chunk(start_i, end_i)
#     305
#     306     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\io\formats\csvs.py in _save_chunk(self, start_i, end_i)
#     313
#     314         ix = self.data_index[slicer]._format_native_types(**self._number_format)
# --> 315         libwriters.write_csv_rows(
#     316             data,
#     317             ix,
#
# c:\Users\Nik\anaconda3\envs\Test\lib\site-packages\pandas\_libs\writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:
